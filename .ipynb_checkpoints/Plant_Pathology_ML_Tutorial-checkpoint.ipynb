# %% [markdown]
# # Tutorial: A Brief Introduction to Image Classification with Machine Learning

# %% [markdown]
# ### Introduction
# In this tutorial, we will learn how to quickly build an image classification pipeline using Python and machine learning. This tutorial will not go into too much depth of the nature of the models, but will mostly serve as a short example to help you get started on your image classification tasks. <br>

# %% [markdown]
# ### Objectives
# During this tutorial, our main objectives will be to: <br>
# <ol>
# <li>Define what an image is and how it is interpreted by a computer.</li>
# <li>Explore what image classification is as a problem and discover some of its challenges.</li>
# <li>Build a simple model to classify between healthy and diseased apple leaves.</li>
# </ol>

# %% [markdown]
# ## 1. A Prior on Images
# Before we dive into image classification, we first need to understand how an image is read on a computer. An image is a matrix of entries, also known as pixels, where each entry has a numerical value. Most often these values are represented by 8-bit integers (ranging from 0 to 255) that represent the intensity at that particular location. An image can be organized into multiple dimensions or "channels". For example, a Red-Green-Blue (RGB) image has 3 channels (Figure 1). The resulting color we see is the sum of the pixel values at that particular location.  <br>

# %% [markdown]
# <center>
# Example Representation of an RGB image (Image by GeeksforGeeks <a href="https://www.geeksforgeeks.org/matlab-rgb-image-representation/"> [MATLAB RGB image representation])</a>.
# </center>
# <br>
# <img src="https://media.geeksforgeeks.org/wp-content/uploads/Pixel.jpg" />

# %% [markdown]
# In computer vision, we’re working with matrices of pixel values. This is how a computer will have to interpret the contents of an image. Imagine making sense of a physical object using only numbers...Not an easy task! Therefore, we need to transform our matrix into a format that the computer can understand and process. <br>

# %% [markdown]
# We can do this with the help of *image descriptors* and *deep learning methods*. By using these tools, we can encode traits such as spatial information, texture and color, and quantify regions of an image. Based on these features, we can then apply machine learning to teach a computer how to recognize images.

# %% [markdown]
# ## 2. Defining the Image Classification Problem

# %% [markdown]
# Image classification aims to assign a label to an image. For example, recognize a "tulip" from a "rose" or a "cancerous region" from a "healthy region" of skin. The applications of image classification are literally infinite, but a strong image classification algorithm depends on good (and often copious amounts of) data. This is because a same object can be represented in an endless amount of settings. This then leads us to the challenges of image classification (Figure 2):

# %% [markdown]
# <ol>
# <li> <b>Viewpoint variation</b>. A single instance of an object can be oriented in many ways with respect to the camera.</li>
# <li> <b>Scale variation</b>. Visual classes often exhibit variation in their size (size in the real world, not only in terms of their extent in the image).</li>
# <li> <b>Deformation</b> Many objects of interest are not rigid bodies and can be deformed in extreme ways.</li>
# <li> <b>Occlusion</b>. The objects of interest can be occluded. Sometimes only a small portion of an object (as little as few pixels) could be visible.</li>
# <li> <b>Illumination conditions</b>. The effects of illumination are drastic on the pixel level.</li>
# <li> <b>Background clutter</b>. The objects of interest may blend into their environment, making them hard to identify.</li>
# <li><b>Intra-class variation</b>. The classes of interest can often be relatively broad, such as chair. There are many different types of these objects, each with their own appearance.</li>
# </ol>
#
#
# A good image classification model must be invariant to the cross product of all these variations, while simultaneously retaining sensitivity to the inter-class variations.

# %% [markdown]
# <center> A representation of the challenges in image classification problems (Image by Stanford University <a href="https://cs231n.github.io/assets/challenges.jpeg"> [Inter-class variations in images]) </a>.
# </center>
# <img src="https://cs231n.github.io/assets/challenges.jpeg" />

# %% [markdown]
# ## 3. Plant Pathology Machine Learning Tutorial

# %% [markdown]
# ### Using a Machine Learning (ML Approach)
#
# In this tutorial, we will load and lightly analyze this plant pathology data from the kaggle
# website: https://www.kaggle.com/skeef79/plant-pathology-more-data-no-background.
# The dataset contains 6193 images (4371 training images, 1822 test images) of apple
# leaves, some which are healthy, infected with apple rust, have apple scab and
# some with more than one disease.A few additional images have been added, and the
# backgrounds have been removed as well. This is a modified dataset from the original data for this kaggle competition:
# https://www.kaggle.com/c/plant-pathology-2020-fgvc7/data.

# %% [markdown]
# ### Code
# First, let's start by installing and importing the libraries that we need:

# %%
# Install necessary libraries
import sys 
# !python -m pip install imutils

# %%
# import the necessary packages
import matplotlib.pyplot as plt # plotting and data visualization
import matplotlib.image as mpimg
from imutils import resize, paths # simple image manipulation 
from sklearn.ensemble import RandomForestClassifier # machine learning and analysis
from sklearn.metrics import classification_report
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import zipfile
import cv2  # image analysis

# %% [markdown]
# #### Load Data
# Next, we will save the paths to our data to disk and define some key constants we'll use.

# %%
# unzip the zip dataset
with zipfile.ZipFile('images.zip', 'r') as zip_ref:
    zip_ref.extractall('images')    
    
# import the paths to the training images and labels adn Load the raw data to disk
trainingImgsPath = "./images/images/train/"
trainingLablsPath = "./train.csv"
trainingImages  = sorted(list(paths.list_images(trainingImgsPath)))

# store everything in a pandas dataframe
trainingLabels = pd.read_csv(trainingLablsPath)

# visualize the data table
display(trainingLabels.head())
# Out:
#   image_id  healthy  multiple_diseases  rust  scab
# 0  Train_0        0                  0     0     1
# 1  Train_1        0                  1     0     0
# 2  Train_2        1                  0     0     0
# 3  Train_3        0                  0     1     0
# 4  Train_4        1                  0     0     0

# %% [markdown]
# We can see that there are four trait categories: Heathy/Unhealthy, Multiple Diseases/Single Disease, Rust/No Rust, Scab/No Scab. Some of these classes are not independant of each other (i.e a healthy leaf can not have any other traits). This is important to take into consideration when building a model.

# %%
# define some important constants related to our dataset
img_size = 784
number_classes = 4
class_labels = ["healthy", "multiple_diseases", "rust", "scab"]

# %% [markdown]
# #### Data Visualization
# Next, we will take a look at some of the images found in our dataset. We will create a simple collage displaying 4 images of each combination of health category and label (negative/positive).

# %%
# create a simple figure showing 4 images of each category type
nsamples = 4
healthy = trainingLabels[trainingLabels["healthy"] == 1].sample(nsamples)
unhealthy = trainingLabels[trainingLabels["healthy"] == 0].sample(nsamples)
mult_disease = trainingLabels[trainingLabels["multiple_diseases"] == 1].sample(nsamples)
one_disease = trainingLabels[trainingLabels["multiple_diseases"] == 0].sample(nsamples)
rust = trainingLabels[trainingLabels["rust"] == 1].sample(nsamples)
no_rust = trainingLabels[trainingLabels["rust"] == 0].sample(nsamples)
scab = trainingLabels[trainingLabels["scab"] == 1].sample(nsamples)
no_scab = trainingLabels[trainingLabels["scab"] == 0].sample(nsamples)

# store all the samples and their labels in a dictionary
samples = {"Healthy": healthy, "Unhealthy": unhealthy, "Multiple Diseases": mult_disease,
"One Disease": one_disease, "Rust": rust, "No Rust": no_rust, "Scab": scab, "No Scab": no_scab}

# %%
# Display some image samples of each category
for i, key in enumerate(samples):
    # create a (1x4) figure window
    fig, ax = plt.subplots(1, nsamples, figsize = (12, 8))

    for j in range(nsamples):
        # load the sample image
        path = trainingImgsPath + samples[key].iloc[j]['image_id'] + ".jpg"
        img = cv2.imread(trainingImgsPath + samples[key].iloc[j]['image_id'] + ".jpg")

        #Do a bit of cleaning
        # convert the image from BGR to RGB format (opencv's default is BGR)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Create a shapening kernel and sharpen the image
        sharpening_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
        img = cv2.filter2D(img, -1, sharpening_kernel)

        # show the image and add a title to the plot
        ax[j].imshow(img)
        ax[j].set_title(key, fontsize=8)
        ax[j].set_xlim([0, 800])
        ax[j].set_ylim([0, 800])
        ax[j].grid(False)

    plt.show()

# %% [markdown]
# Here we have a sample of all the apple leaf types. We can see from the set of images that there are some variations in leaf color, shape, texture, etc. We can also see that leaves with a type of sickness have spots of different colors and sizes depending on the nature of the disease. We may be able to use this to our advantage while building our classifier.

# %% [markdown]
# Finally, let's take a look at how our samples are distributed. It is important to check this to see whether we may have unbalanced classes which could negatively affect training. Here, we will create a histogram plot of all four classes together:

# %%
# show the distribution of the field categories
ax = trainingLabels[class_labels].apply(pd.value_counts).plot.bar(figsize=(10, 6)) 

# clean up the figure a bit
ax.set_title("Class Distributions")
ax.set_ylabel("Counts")
ax.set_xlabel("Label")
ax.set_xticklabels(["False", "True"], rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# Looking at the bar charts, we can see that the unhealthy vs healthy class is
# well balanced, but the other classes (multiple_diseases, rust and scab) have a lot
# more negative values than positive ones. For now, we will attempt to solve a *binary classification* problem and use ml to differentiate between healthy/unhealthy leaves only.

# %% [markdown]
# ### Build a Simple Image Descriptor

# %% [markdown]
# We will create a simple RGB histogram image descriptor. A color histogram can be used to count the number of times a specific pixel intensity occurs in an image. In this case, we will be doing this calculation for each channel in the image (Red-Green-Blue). So to put it simply, we will be calculating how many pixels of each color occur in a healthy plant image, and an unhealthy plant image. The counts for each color/color range will be used as our feature vector, which we will pass to our ML model. A graphical representation of a color histogram is given below.

# %% [markdown]
# <center> Example Representation of an RGB image histogram </center>
# <img src="https://upload.wikimedia.org/wikipedia/commons/f/f5/Odd-eyed_cat_histogram.png" />

# %% [markdown]
# <center>
#  By <a href="//commons.wikimedia.org/w/index.php?title=User:Muenteroman&amp;action=edit&amp;redlink=1" class="new" title="User:Muenteroman (page does not exist)">Muenteroman</a> - <span class="int-own-work" lang="en">Own work</span>, File:Odd-eyed cat by ihasb33r.jpg, <a href="https://creativecommons.org/licenses/by-sa/4.0" title="Creative Commons Attribution-Share Alike 4.0">CC BY-SA 4.0</a>, <a href="https://commons.wikimedia.org/w/index.php?curid=43793434">Link</a>
# </center>

# %% [markdown]
# Here, we will be constructing a 3D color histogram containing 8 bins per channel, which will produce feature vector of dims 8 x 8 x 8, or 512 when flattened. This is pretty handy, since the size of our original image is (800 x 800 pixels) x 3 channels or, 1 920 000 pixels. We are saving our computer a ton of memory space! If we had larger images (1920 x 1080 for example), it would be wise to reduce the image size to a more manageable dimension to increase the speed of the histogram computation.

# %%
# Create a class for constructing our image descriptor. We will pass this descriptor to our classification model.

class RGBHist:
    def __init__(self, bins):
        # specify the number of bins that we will need to build the histogram
        self.bins = bins

    def describe(self, image):
        # compute a 3D histogram for each image using the 3 color spaces (R, G, B)
        # in the image. Normalize the histogram to accomodate multiple image
        # sizes if that is the case.
        histogram = cv2.calcHist([image], [0, 1, 2], None, self.bins, [0, 256, 0, 256, 0, 256])
        cv2.normalize(histogram, histogram)

        # return out 3D histogram as a flattened array
        return histogram.flatten()

# %%
# initialize the image descriptor
desc = RGBHist([8, 8, 8])

# %% [markdown]
# Here we will define a function to create our training dataset. We will loop through the images, describe them using our image descriptor, and then pass the feature vectors to a Random Forest Classifier. Let's give this a go!

# %%
# Function to help construct our training matrix
def create_training_data(trainingImgsPath, trainingLablsPath, descriptor):
    # create an empty list to store the images and labels
    trainingfeatures = []

    # sort the image paths so that they are matched with the correct label
    imagePaths = sorted(list(paths.list_images(trainingImgsPath)))

    # loop through the images and load them to disk
    for image in imagePaths:
        if "Test" in image: 
            pass
        else:
            img = cv2.imread(image)

            # convert the image from BGR to RGB format (opencv's default is BGR)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

            if descriptor:
                # describe the image and update the list of features
                features = descriptor.describe(img)
                trainingfeatures.append(features)
            else: 
                # if there is no descriptor then return the loaded image only and resize the image to half width/height 
                img = resize(img, width=150)
                trainingfeatures.append(img)

    # load the training labels and only keep the 1st category
    trainingLabels = pd.read_csv(trainingLablsPath)
    trainingLabels = trainingLabels[["healthy"]].to_numpy().astype("uint8")

    return (trainingfeatures, trainingLabels)

# %%
(X_train, y_train) = create_training_data(trainingImgsPath, trainingLablsPath, desc)

# %% [markdown]
# ### Train the model

# %% [markdown]
# Next, we create a train/test split and train our model. We are putting aside a chunk of our data (25%) to use for evaluating its performance.

# %%
# construct the training and testing splits
(trainData, testData, trainTarget, testTarget) = train_test_split(X_train, y_train,
	test_size=0.25, shuffle = True)

print("Length of training data: ", len(trainData))
print("Length of validation data: ", len(testData))
# Out:
# Length of training data:  3278
# Length of validation data:  1093

# %%
# train the classifier
RF_model = RandomForestClassifier(n_estimators=50, random_state=84)
RF_model.fit(trainData, trainTarget.ravel())
target_names = ['unhealthy', 'healthy']

# %% [markdown]
# ### Evaluate the model
# The last step is checking to see how well our model did. We can use some handy functions from scikit-learn to do this pretty easily!

# %%
# evaluate the classifier
print(classification_report(testTarget, RF_model.predict(testData),
	target_names = target_names))
# Out:
#               precision    recall  f1-score   support
#
#    unhealthy       0.81      0.96      0.88       563
#      healthy       0.94      0.76      0.84       530
#
#     accuracy                           0.86      1093
#    macro avg       0.88      0.86      0.86      1093
# weighted avg       0.87      0.86      0.86      1093

# %%
# show the confusion matrix 
from sklearn.metrics import confusion_matrix
confusion_matrix(testTarget, RF_model.predict(testData))
# Out:
# array([[538,  25],
#        [125, 405]])

# %%
disp = plot_confusion_matrix(RF_model, testData, testTarget,
                                 display_labels=target_names,
                                 cmap=plt.cm.Blues, values_format =".0f")
disp.ax_.set_title("Confusion Matrix for the Random Forests Model")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for the Random Forests Model')

# %% [markdown]
# Even with a simple RGB descriptor and Random Forest classifier, we were able to produce a model with an accuracy of 83%! Not bad. But maybe we can do better? Another very popular model that usually works well with images is the *Convolutional Neural Network*. Let's see if we can use it to improve our results.

# %% [markdown]
# ### Using a Deep Learning (DL) Approach
#
# #### Introduction to Convolutional Neural Networks

# %% [markdown]
# Convolutional neural networks take advantage of the spatial patterns organized within an image. A CNN is composed of CONV and POOl layers primarily. The CONV layers learn specific filters that help extract key features without having to design these features ourselves. The POOL layers perform dimensionality reduction on the image after every set of convolutions. In the context of image classification, our CNN may learn to detect features like edges, shapes, textures or patterns, or even higher-level features like spatial patterns in the higher layers of the network. The  very last layer is a classifier that uses these higher-level features to make predictions regarding the contents of the image.
#
# In practice, CNNs give us two key benefits: local invariance and compositionality.

# %% [markdown]
# <center>
# How a Convolutional Neural Network Works (Image by Wikipedia Commons) <a title="Aphex34, CC BY-SA 4.0 &lt;https://creativecommons.org/licenses/by-sa/4.0&gt;, via Wikimedia Commons" href="https://commons.wikimedia.org/wiki/File:Typical_cnn.png"><img width="1024" alt="Typical cnn" src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/63/Typical_cnn.png/1024px-Typical_cnn.png"></a>.
# </center>
# <br>

# %% [markdown]
# #### Train the CNN

# %% [markdown]
# We will create a new training matrix using only the original images reducing the image size from 784x784 to 150x150 pixels.

# %%
(X_train, y_train) = create_training_data(trainingImgsPath, trainingLablsPath, descriptor=None)

# %%
# construct the training and testing splits
(trainData, testData, trainTarget, testTarget) = train_test_split(X_train, y_train,
	test_size=0.25, shuffle = True)

# %% [markdown]
# #### Assign a New Training Size

# %% [markdown]
# Since training a CNN usually takes up a lot of space in memory, we will reduce the size of our images to half of the original pixel size. We will feed the images directly to the CNN and see what quality of predictions we get.

# %%
new_img_dim = (150, 150, 3)

# %% [markdown]
# #### Build the CNN

# %%
from keras import layers
from keras import models
from keras import optimizers

# Build the CNN 
CNN_model = models.Sequential()
CNN_model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=new_img_dim))
CNN_model.add(layers.MaxPooling2D((2, 2)))
CNN_model.add(layers.Conv2D(64, (3, 3), activation='relu'))
CNN_model.add(layers.MaxPooling2D((2, 2)))
CNN_model.add(layers.Flatten())
CNN_model.add(layers.Dense(128, activation ="relu"))
CNN_model.add(layers.Dense(1, activation="softmax"))
CNN_model.summary()
# Out:
# Using TensorFlow backend.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 82944)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               10616960
# _________________________________________________________________
# ...

# %%
# compile the model 
CNN_model .compile(optimizer="rmsprop",
              loss="binary_crossentropy",
             metrics =["accuracy"])

# %% [markdown]
# Next, we will reshape and preprocess our training data to be able to successfully pass it to the CNN:

# %%
# create our training and validation set for the CNN 
train_images = np.array(trainData).reshape((len(trainData), new_img_dim[0], new_img_dim[1], new_img_dim[2])) 
test_images = np.array(testData).reshape((len(testData), new_img_dim[0], new_img_dim[1], new_img_dim[2]))

# %% [markdown]
# Standardization of a dataset is a common requirement for many machine learning estimators: they might behave badly if the
# individual features do not more or less look like normally distributed data. Here we standardize the image matrix by
# dividing all pixel values by the max pixel value, and setting all values between 0 and 1. This process is also called *Min-Max scaling*.

# %%
train_images = train_images.astype('float32')/255
test_images = test_images.astype('float32')/255

# %%
# Train the model 
history = CNN_model.fit(train_images, trainTarget, epochs=10,batch_size=64)
# Out:
# Epoch 1/10
# 3278/3278 [==============================] - 41s 13ms/step - loss: 7.7882 - accuracy: 0.4921
# Epoch 2/10
# 3278/3278 [==============================] - 41s 12ms/step - loss: 7.7882 - accuracy: 0.4921
# Epoch 3/10
# 3278/3278 [==============================] - 42s 13ms/step - loss: 7.7882 - accuracy: 0.4921
# Epoch 4/10
# 3278/3278 [==============================] - 41s 12ms/step - loss: 7.7882 - accuracy: 0.4921
# Epoch 5/10
# 3278/3278 [==============================] - 40s 12ms/step - loss: 7.7882 - accuracy: 0.4921
# Epoch 6/10
# 3278/3278 [==============================] - 41s 12ms/step - loss: 7.7882 - accuracy: 0.4921
# Epoch 7/10
# 3278/3278 [==============================] - 74s 23ms/step - loss: 7.7882 - accuracy: 0.4921
# Epoch 8/10
# 3278/3278 [==============================] - 113s 35ms/step - loss: 7.7882 - accuracy: 0.4921
# Epoch 9/10
# 3278/3278 [==============================] - 168s 51ms/step - loss: 7.7882 - accuracy: 0.4921
# Epoch 10/10
# ...

# %% [markdown]
# Finally, let's compare how the CNN performs on the test data to see if it has learned how to generalize better.

# %%
# evaluate the classifier
test_loss, test_acc = CNN_model.evaluate(test_images, testTarget)
print("Loss on the test set: ", test_loss)
print("Accuracy on the set: \n", test_acc)

print("Classification Report")
CNN_predictions = CNN_model.predict(test_images)
print(classification_report(testTarget, CNN_predictions,
	target_names = target_names))

confusion_matrix(testTarget, CNN_predictions)
# Out:
# 1093/1093 [==============================] - 6s 5ms/step
# Loss on the test set:  7.603691724932532
# Accuracy on the set:
#  0.5013723969459534
# Classification Report
#               precision    recall  f1-score   support
#
#    unhealthy       0.00      0.00      0.00       545
#      healthy       0.50      1.00      0.67       548
#
#     accuracy                           0.50      1093
#    macro avg       0.25      0.50      0.33      1093
# weighted avg       0.25      0.50      0.33      1093
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# From what we have observed above, we can see that training a CNN on this dataset will not be a trivial task. Some of the reasons for this could be:
#
# <ol>
# <li> Our network may not be deep enough to learn features that could differentiate between the two classes. </li>
# <li> The model doesn't seem to be learning, it is primarily choosing the majority class within our dataset. This is a common problem in machine learning. </li>
# <li> More hyperparameter tuning or a change in architecture might be needed to come up with a better model. </li>
# <li> We could be stopping training too early. </li>
# <li> We might just not have enough data. </li>
#
# Let's visualize the loss of the model during training to see if this could give us any more information on what happened:

# %%
# Visualize the loss during training 
history_dict = history.history

loss_values = history_dict["loss"]
accuracy = history_dict["accuracy"]
epochs = range(1, len(loss_values)+1) 

plt.plot(epochs, loss_values, 'bo', label="Training Loss")
plt.plot(epochs, accuracy, 'r', label="Accuracy")
plt.title("CNN training loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# How could we maybe improve our model classification?
#
# <ol>
# <li> Use data augmentation to generate more images to train with. </li>
# <li> Maybe consider using a pre-trained network as a feature extractor and build a new classifier. </li>
# <li> Add forms of regularization to the model such as dropout. </li>
# <li> Maybe this model architecture is not the best for our given problem! </li>
# </ol>

# %% [markdown]
# ### In Conclusion
#
# In summary, machine learning is a very powerful tool that can help us to solve an infinite amount of problems. However, it is important to take the time to really understand the type of task at hand, and use any knowledge we might have about our data to develop the best fitting pipeline. It is also important to try all kinds of models before you explore one fully, sometimes a simple model might be the best answer, just as we've seen in this example.
